# %%
import sys
from pathlib import Path

# Find project root = parent folder of "notebooks"
PROJECT_ROOT = Path.cwd().parent
SRC_DIR = PROJECT_ROOT / "src"

# Add src/ to sys.path if missing
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print("PROJECT_ROOT =", PROJECT_ROOT)
print("SRC_DIR added to path:", SRC_DIR in map(Path, map(Path, sys.path)))
# Out:
# PROJECT_ROOT = C:\Users\Антон\OneDrive\Документы\Machine Learning\Projects\imdb-sentiment
# SRC_DIR added to path: True

# %%
from data_loader import get_data_dir
from preprocess import basic_clean
from models.baseline import build_baseline_pipeline, BaselineConfig

print("Data dir:", get_data_dir())
print("Clean sample:", basic_clean("   Hello IMDB   "))
print("Pipeline:", build_baseline_pipeline())
# Out:
# Data dir: C:\Users\Антон\OneDrive\Документы\Machine Learning\Projects\imdb-sentiment\data
# Clean sample: Hello IMDB
# Pipeline: Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=20000, ngram_range=(1, 2))),
#                 ('logreg',
#                  LogisticRegression(max_iter=1000, n_jobs=-1,
#                                     random_state=42))])
